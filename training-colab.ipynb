# %%
# Install the required library
# !pip install timm

# Download the dataset (this is super fast on Colab's network)
# !python download_data.py

# Train the model (this will use the free GPU)
# !python train.py
# Out:
# ...
# Starting download from huggingface: https://huggingface.co/datasets/mohanty/PlantVillage/resolve/main/data.zip
# Downloading... 100%
# Download finished.
# Extracting zip file...
# Done extracting.
# Found the plant folders here: /content/data/_temp/extracted/raw/color
#
# Saved total tomato images: 18160
# Breakdown per class:
#  - Tomato___Bacterial_spot: 2127
#  - Tomato___Early_blight: 1000
#  - Tomato___Late_blight: 1909
#  - Tomato___Leaf_Mold: 952
#  - Tomato___Septoria_leaf_spot: 1771
#  - Tomato___Spider_mites Two-spotted_spider_mite: 1676
#  - Tomato___Target_Spot: 1404
#  - Tomato___Tomato_Yellow_Leaf_Curl_Virus: 5357
#  - Tomato___Tomato_mosaic_virus: 373
#  - Tomato___healthy: 1591
# Cleaning up temp stuff...
# Done downloading data.
# Using device: cuda
# Loaded dataset from: /content/data/tomato
# Total images = 18160
# Train Size: 14528
# Val Size: 3632
# ...
